# %%
T=[1419.8868881405,
1419.8947006405,
1419.9025131405,
1419.9103256405,
1419.9181381405,
1419.9259506405,
1419.9337631405,
1419.9415756405,
1419.9493881405,
1419.9572006405,
1419.9650131405,
1419.9728256405,
1419.9806381405,
1419.9884506405,
1419.9962631405,
1420.0040756405,
1420.0118881405,
1420.0197006405,
1420.0275131405,
1420.0353256405,
1420.0431381405,
1420.0509506405,
1420.0587631405,
1420.0665756405,
1420.0743881405,
1420.0822006405,
1420.0900131405,
1420.0978256405,
1420.1056381405,
1420.1134506405,
1420.1212631405,
1420.1290756405,
1420.1368881405,
1420.1447006405,
1420.1525131405,
1420.1603256405,
1420.1681381405,
1420.1759506405,
1420.1837631405,
1420.1915756405,
1420.1993881405,
1420.2072006405,
1420.2150131405,
1420.2228256405,
1420.2306381405,
1420.2384506405,
1420.2462631405,
1420.2540756405,
1420.2618881405,
1420.2697006405,
1420.2775131405,
1420.2853256405,
1420.2931381405,
1420.3009506405,
1420.3087631405,
1420.3165756405,
1420.3243881405,
1420.3322006405,
1420.3400131405,
1420.3478256405,
1420.3556381405,
1420.3634506405,
1420.3712631405,
1420.3790756405,
1420.3868881405,
1420.3947006405,
1420.4025131405,
1420.4103256405,
1420.4181381405,
1420.4259506405,
1420.4337631405,
1420.4415756405,
1420.4493881405,
1420.4572006405,
1420.4650131405,
1420.4728256405,
1420.4806381405,
1420.4884506405,
1420.4962631405,
1420.5040756405,
1420.5118881405,
1420.5197006405,
1420.5275131405,
1420.5353256405,
1420.5431381405,
1420.5509506405,
1420.5587631405,
1420.5665756405,
1420.5743881405,
1420.5822006405,
1420.5900131405,
1420.5978256405,
1420.6056381405,
1420.6134506405,
1420.6212631405,
1420.6290756405,
1420.6368881405,
1420.6447006405,
1420.6525131405,
1420.6603256405,
1420.6681381405,
1420.6759506405,
1420.6837631405,
1420.6915756405,
1420.6993881405,
1420.7072006405,
1420.7150131405,
1420.7228256405,
1420.7306381405,
1420.7384506405,
1420.7462631405,
1420.7540756405,
1420.7618881405,
1420.7697006405,
1420.7775131405,
1420.7853256405,
1420.7931381405,
1420.8009506405,
1420.8087631405,
1420.8165756405,
1420.8243881405,
1420.8322006405,
1420.8400131405,
1420.8478256405,
1420.8556381405,
1420.8634506405,
1420.8712631405,
1420.8790756405,
1420.8868881405,
1420.8947006405,
1420.9025131405,
1420.9103256405,
1420.9181381405,
1420.9259506405,
1420.9337631405,
1420.9415756405,
1420.9493881405,
1420.9572006405,
1420.9650131405] #Les frequences recueillis experimentalement grace au telescope

temper=[50.7804009763,
51.0266089811,
50.9035049787,
50.7188489751,
51.2728169858,
50.7804009763,
51.3959209882,
51.0881609822,
51.9498889988,
51.5190249905,
52.3192010059,
53.1193770213,
52.5038570095,
53.2424810237,
53.4886890284,
53.6733450319,
54.7812810532,
54.9659370568,
55.3352490639,
55.2121450615,
55.1505930603,
55.9507690757,
55.2121450615,
55.5199050674,
55.2121450615,
54.7197290521,
55.9507690757,
55.5199050674,
55.9507690757,
56.6893930899,
56.6278410888,
57.058705097,
57.6742251089,
57.366465103,
59.0283691349,
59.397681142,
57.4280171041,
57.4280171041,
57.1818090994,
57.4280171041,
57.3049131018,
57.9819851148,
58.4128491231,
57.7973291112,
58.4744011243,
58.8437131314,
59.1514731373,
59.3361291408,
59.8900971515,
58.9052651325,
58.5359531254,
58.2897451207,
57.8588811124,
58.2897451207,
57.1818090994,
57.4280171041,
57.5511211065,
57.5511211065,
57.5511211065,
57.5511211065,
58.2281931195,
58.9052651325,
58.3512971219,
57.7973291112,
57.4895691053,
57.1202570982,
56.0738730781,
55.6430090698,
54.8428330544,
53.4271370272,
52.4423050083,
52.3192010059,
51.7652329953,
51.7036809941,
51.9498889988,
52.1345450024,
51.9498889988,
52.1960970035,
52.1345450024,
52.1345450024,
51.5805769917,
51.2728169858,
52.5654090106,
52.2576490047,
52.8116170154,
53.1809290225,
53.5502410296,
53.1809290225,
53.7964490343,
53.3040330248,
53.2424810237,
53.4886890284,
53.3040330248,
53.1809290225,
52.9347210177,
52.3807530071,
52.6269610118,
53.2424810237,
53.3040330248,
52.8116170154,
52.8116170154,
53.2424810237,
52.6269610118,
52.6269610118,
52.3192010059,
49.9802249609,
49.9802249609,
49.9802249609,
50.8419529775,
50.9650569799,
49.9802249609,
50.4726409704,
50.349536968,
49.9802249609,
49.672464955,
50.349536968,
50.7188489751,
50.1033289633,
50.349536968,
50.1648809645,
49.9802249609,
49.9802249609,
49.9802249609,
49.9802249609,
49.9802249609,
49.9802249609,
49.9802249609,
49.9802249609,
49.9802249609,
49.9802249609,
49.9802249609,
50.349536968,
50.0417769621,
49.7340169562,
49.672464955,
50.4110889692,
49.2416009467,
49.5493609527,
49.9802249609,
] #Temperature obtenu experimentalement

# %%
# %matplotlib inline
from pylab import *
c=3*10**5 #Vitesse de la lumière
Femise=(1/0.21)*(10**(3)) #Frequence Raie 21 cm en MHz

def frequ_en_vitesse(L):
    LB=[]
    for i in L:
        LB.append((c*(Femise-i))/Femise) #Grace a la formule de l'effet Doppler on transforme chaque frequence en
    return LB                            #vitesse radiale.On l'utilise car elle nous permet de transformer la frequence
                                         #recue en vitesse radiale.
V=frequ_en_vitesse(T)

figure(figsize=(12,6), dpi=60)
plot(V,temper,'ko')
plot(V,temper,'k-',linewidth=0.5, label="Température en fonction de la vitesse radiale",)
plt.title("Graphe de la temperature en fonction de la vitesse radiale du nuage de gaz (K par Km/s)")
plt.legend(loc="upper left")
show()
